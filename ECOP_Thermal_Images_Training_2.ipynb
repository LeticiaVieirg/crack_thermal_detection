# %% [markdown]
# <a href="https://colab.research.google.com/github/LeticiaVieirg/crack_thermal_detection/blob/main/ECOP_Thermal_Images_Training_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Treinamento com o dataset desenvolvido

# %% [markdown]
# 1. Importação das bibliotecas

# %%
import cv2
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization, Activation, Add, Input, AveragePooling2D
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import regularizers

import numpy as np
import os, sys
from scipy import ndimage
import cv2
import matplotlib.pyplot as plt
import itertools
import scipy.stats
import tensorflow as tf
from keras import applications, optimizers, Input
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils.multiclass import unique_labels
import pandas as pd

# %% [markdown]
# 2. Carregando o dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder=r'/content/drive/MyDrive/dataset/dataset'

# %% [markdown]
# 3. Estruturando o dataset

# %%
#image resolution
image_width = 48
image_height = 48
channels = 3 #rgb

train_files = []
i=0
for classes in ['Positive', 'Negative']:
    print(os.path.join(folder, classes))
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes)) if os.path.isfile(os.path.join(folder, classes, f ))]
    for _file in onlyfiles:
        train_files.append(_file)

dataset = np.ndarray(shape=(len(train_files), image_height, image_width, channels),
                     dtype=np.float32)
y_dataset = []
# Out:
# /content/drive/MyDrive/dataset/dataset/Positive
# /content/drive/MyDrive/dataset/dataset/Negative

# %%
i = 0
for classes in ['Positive', 'Negative']:
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes)) if os.path.isfile(os.path.join(folder, classes, f))]
    for _file in onlyfiles:
        img_path = os.path.join(folder, classes, _file)
        img = load_img(img_path, target_size=(image_height, image_width))
        x = img_to_array(img)
        dataset[i] = x
        mapping = {'Positive': 0 , 'Negative' : 1}
        y_dataset.append(mapping[classes])
        i += 1
        if i == 30000:
            print("%d images to array" % i)
            break

print("All images to array!")
# Out:
# All images to array!

# %% [markdown]
# 6. Normalizando os dados

# %%
#Normalização
dataset = dataset.astype('float32')
dataset /= 255

# %%
classes = ['Positive', 'Negative']

# Dicionário para armazenar o índice da primeira imagem de cada classe
first_image_index = {}

# Encontra o índice da primeira imagem de cada classe
for i, label in enumerate(y_dataset):
    if label not in first_image_index:
        first_image_index[label] = i

# Configura a grade para exibir as imagens
num_classes = len(set(y_dataset))
fig, axs = plt.subplots(5, 5, figsize=(8, 8))
for i, ax in enumerate(axs.flat):
    ax.imshow(dataset[i])
    ax.axis('off')  # Desativa os eixos
    ax.set_title(classes[y_dataset[i]])

plt.suptitle('Positive Images', fontsize=14, fontweight='regular', y=1)
plt.tight_layout()
plt.show()

# %%
# plot images from negative class
fig, axs = plt.subplots(5, 5, figsize=(8, 8))
for i, ax in enumerate(axs.flat):
    ax.imshow(dataset[first_image_index[1] + i])
    ax.axis('off')  # Desativa os eixos
    ax.set_title(classes[y_dataset[first_image_index[1] + i]])

plt.suptitle('Negative Images', fontsize=14, fontweight='regular', y=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# 7. Normalizando o dataset

# %%
# categorical values
n_classes = len(set(y_dataset))
print(n_classes)

y_dataset_ = to_categorical(y_dataset, n_classes)
# Out:
# 2

# %%
# Trim dataset to match the size of y_dataset_
dataset_trimmed = dataset[:len(y_dataset_)]

# Now both dataset_trimmed and y_dataset_ have the same size
# You can then proceed with splitting or any other operations

# Splitting into training and test sets
X_train, X_test, y_train, y_test = train_test_split(dataset_trimmed, y_dataset_, test_size=0.2)

print("Train set size: {0}, Test set size: {1}".format(len(X_train), len(X_test)))
# Out:
# Train set size: 128, Test set size: 32

# %%
from sklearn.utils import resample

# Criar listas vazias para armazenar as amostras balanceadas
balanced_X_train = []
balanced_y_train = []

# Determinar o número de amostras na classe majoritária
majority_samples = 1000

# Iterar sobre cada classe
for class_label in np.unique(y_train.argmax(axis=1)):
    # Filtrar amostras pertencentes a essa classe
    X_class = X_train[y_train.argmax(axis=1) == class_label]
    y_class = y_train[y_train.argmax(axis=1) == class_label]

    # Calcular o número de amostras na classe menos representada
    minority_samples = len(X_class)

    # Balancear as amostras aumentando a classe menos representada
    balanced_X_class, balanced_y_class = resample(X_class, y_class,
                                                  replace=True,
                                                  n_samples=majority_samples,
                                                  random_state=42)

    # Adicionar amostras balanceadas à lista
    balanced_X_train.extend(balanced_X_class)
    balanced_y_train.extend(balanced_y_class)

# Converter listas em arrays numpy
balanced_X_train = np.array(balanced_X_train)
balanced_y_train = np.array(balanced_y_train)

# Embaralhar amostras
shuffled_indices = np.arange(len(balanced_X_train))
np.random.shuffle(shuffled_indices)
balanced_X_train = balanced_X_train[shuffled_indices]
balanced_y_train = balanced_y_train[shuffled_indices]

# Verificar o tamanho dos conjuntos de dados balanceados
print("Tamanho do conjunto de treinamento balanceado:", len(balanced_X_train))
print("Tamanho do conjunto de teste:", len(X_test))

for class_label in np.unique(balanced_y_train.argmax(axis=1)):
    count = np.sum(balanced_y_train.argmax(axis=1) == class_label)
    print(f"Classe {class_label}: {count} amostras")
# Out:
# Tamanho do conjunto de treinamento balanceado: 2000
# Tamanho do conjunto de teste: 32
# Classe 0: 1000 amostras
# Classe 1: 1000 amostras

# %%
# Criar o modelo
model = Sequential()

model.add(BatchNormalization(input_shape=(image_height, image_width, 3)))
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))  # Adiciona a camada de dropout
model.add(Dense(2, activation='sigmoid'))  # Especifica 'softmax' como a função de ativação

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ batch_normalization                  │ (None, 48, 48, 3)           │              12 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 48, 48, 512)         │          14,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 24, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 24, 24, 256)         │       1,179,904 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 36864)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │       1,179,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,373,998 (9.06 MB)
#  Trainable params: 2,373,992 (9.06 MB)
#  Non-trainable params: 6 (24.00 B)

# %% [markdown]
# 4. Compilando o modelo

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Treinando o modelo
from tensorflow.keras.callbacks import EarlyStopping

# Configurar EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True) # paciente entre 5 - 10 é o ideal

# Treinar o modelo
history = model.fit(balanced_X_train, balanced_y_train,validation_split= 0.2, epochs=100, callbacks=[early_stopping], batch_size=64)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9989 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9969 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9948 - loss: 0.0225 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9936 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9973 - loss: 0.0126 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9992 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9989 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9917 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9983 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9982 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9982 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9942 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9727 - loss: 0.0993 - val_accuracy: 1.0000 - val_loss: 0.0112
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9846 - loss: 0.0428 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9841 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9551 - loss: 0.0270 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9844 - loss: 0.0369 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9882 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9900 - loss: 0.0171 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9932 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9939 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9972 - loss: 0.0110 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9814 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9861 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9887 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9970 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9986 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9967 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9961 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9973 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9942 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9909 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9895 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9932 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9914 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9962 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9855 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9765 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9771 - loss: 0.0241 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9966 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9973 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9973 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9958 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9954 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9977 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9970 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9953 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9944 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9940 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9971 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9968 - loss: 0.0127 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9988 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9990 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9956 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9990 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9973 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9974 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9947 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9996 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9972 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9967 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9945 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9945 - loss: 0.0141 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9967 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9980 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9978 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9995 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9981 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9985 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9998 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9980 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9975 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9967 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9988 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9969 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9990 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9980 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9957 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9987 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9978 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9993 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9988 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9979 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9927 - loss: 0.0131 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9918 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9932 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9990 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9932 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9987 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9984 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9967 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9956 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9963 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9962 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9855 - loss: 0.0124 - val_accuracy: 0.9775 - val_loss: 0.0021
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9848 - loss: 0.0230 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9994 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9977 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9962 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 0.0021

# %%
# salvar o history csv
history_df = pd.DataFrame(history.history)
history_df.to_csv('history.csv', index=False)

# %% [markdown]
# 5. Carregando o modelo

# %%
# save model structure in jason file
model_json = model.to_json()
with open("thermal_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
model.save('modelosalvo.keras')

# %%
from keras.models import load_model
modelo_carregado = load_model('modelosalvo.keras')

# %%
import pandas as pd
history = pd.read_csv('/content/datasetThermal.csv')

# %% [markdown]
# 6. Plotando o modelo

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5))
plt.plot(history['loss'], '--')         # Acessa a coluna 'loss' do DataFrame
plt.plot(history['val_loss'])           # Acessa a coluna 'val_loss' do DataFrame
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(5, 5))
plt.plot(history['accuracy'], '--')
plt.plot(history['val_accuracy'])
plt.ylabel('Acuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# 7. Salvando o modelo

# %%
preds = modelo_carregado.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step

# %%
#Função da Matriz de Confusão

def plot_confusion_matrix(
        cm,
        classes,
        normalize=False,
        title='Confusion matrix',
        cmap=plt.cm.Blues
    ):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    #plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Real class')
    plt.xlabel('Predict class')

# %%
#Gráfico da Matriz de Confusão

y_test_ = [np.argmax(x) for x in y_test]
preds_ = [np.argmax(x) for x in preds]

cm = confusion_matrix(y_test_, preds_)
plot_confusion_matrix(cm, classes=['Positive', 'Negative'], title='Confusion matrix')
plt.show()
plt.close()
# Out:
# Confusion matrix, without normalization
# [[23  0]
#  [ 4  5]]

# %%
# Métricas de avaliação f1, precision, recall, accuracy

accuracy = accuracy_score(y_test_, preds_)
precision = precision_score(y_test_, preds_, average='weighted')
recall = recall_score(y_test_, preds_, average='weighted')
f1 = f1_score(y_test_, preds_, average='weighted')
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1: {f1}')
# Out:
# Accuracy: 0.875
# Precision: 0.8935185185185185
# Recall: 0.875
# F1: 0.8621428571428571

# %%
#Resultado das predições

n = 4
for t in range(4):
    plt.figure(figsize=(4,4))
    for i in range(n*t, n*(t+1)):
        plt.subplot(1, n, i + 1 - n*t)
        plt.imshow(cv2.cvtColor(X_test[i], cv2.COLOR_BGR2RGB), cmap='Spectral')
        plt.title('Real: {}\nPredict: {}'.format(classes[np.argmax(y_test[i])], classes[np.argmax(preds[i])]), fontsize=7)
        plt.axis('off')
    plt.tight_layout()
    plt.show()
