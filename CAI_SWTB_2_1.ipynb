# %% [markdown]
# <a href="https://colab.research.google.com/github/LeticiaVieirg/crack_thermal_detection/blob/main/CAI_SWTB_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization, Activation, Add, Input, AveragePooling2D
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import regularizers

import numpy as np
import os, sys
from scipy import ndimage
import cv2
import matplotlib.pyplot as plt
import itertools
import scipy.stats
import tensorflow as tf
from keras import applications, optimizers, Input
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils.multiclass import unique_labels

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder='/content/drive/Shareddrives/Leticia_Vieira_G_Pesquisa/dataset/CAI-SWTB-Dataset/Train'

# %%
#image resolution
image_width = 48
image_height = 48
channels = 3 #rgb

train_files = []
i=0
for classes in ['Faulty', 'Healthy']:
    print(os.path.join(folder, classes))
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes)) if os.path.isfile(os.path.join(folder, classes, f ))]
    for _file in onlyfiles:
        train_files.append(_file)

dataset = np.ndarray(shape=(len(train_files), image_height, image_width, channels),
                     dtype=np.float32)
y_dataset = []
# Out:
# /content/drive/Shareddrives/Leticia_Vieira_G_Pesquisa/dataset/CAI-SWTB-Dataset/Train/Faulty
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d192d6edc895> in <cell line: 0>()
#       8 for classes in ['Faulty', 'Healthy']:
#       9     print(os.path.join(folder, classes))
# ---> 10     onlyfiles = [f for f in os.listdir(os.path.join(folder, classes)) if os.path.isfile(os.path.join(folder, classes, f ))]
#      11     for _file in onlyfiles:
#      12         train_files.append(_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/Shareddrives/Leticia_Vieira_G_Pesquisa/dataset/CAI-SWTB-Dataset/Train/Faulty'

# %%
i = 0

valid_extensions=(".jpg", ".jpeg", ".png", ".bmp")

for classes in ['Faulty', 'Healthy']: #catregorias das imagens
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes))
     if f.lower().endswith(valid_extensions) and
             os.path.isfile(os.path.join(folder, classes, f))]

    #if os.path.isfile(os.path.join(folder, classes, f))] #seleciona as imagens e ignora pastas
    for _file in onlyfiles: #Percorre os arquivos da pasta
        img_path = os.path.join(folder, classes, _file)
        img = load_img(img_path, target_size=(image_height, image_width)) #redimenciona a iamgem
        x = img_to_array(img)

        dataset[i] = x #armazenando os dados
        mapping = {'Faulty': 0 , 'Healthy': 1} #dicionario
        y_dataset.append(mapping[classes])  #rotulo das imagens

        i += 1
        if i == 30000:
            print("%d images to array" % i)
            break

print("All images to array!")
# Out:
# All images to array!

# %%
#Normalização
dataset = dataset.astype('float32')
dataset /= 255

# %%
classes = ['Faulty', 'Healthy']

# Dicionário para armazenar o índice da primeira imagem de cada classe
first_image_index = {}

# Encontra o índice da primeira imagem de cada classe
for i, label in enumerate(y_dataset):
    if label not in first_image_index:
        first_image_index[label] = i

# Configura a grade para exibir as imagens
num_classes = len(set(y_dataset))
num_images_per_class = 1
num_cols = num_classes
num_rows = num_images_per_class

# %%
# Cria uma figura com uma grade de subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(5, 15))

# Loop através de cada classe
for i in range(num_classes):
    # Obtém o índice da primeira imagem da classe
    idx = first_image_index[i]

    # Obtém a imagem e converte para RGB
    pixels = dataset[idx]

    # Exibe a imagem no subplot correspondente
    axes[i].imshow(pixels, cmap='Spectral')
    axes[i].axis('off')

    # Adiciona um título para o subplot com o rótulo
    axes[i].set_title(f'{classes[i]}')

# Exibe a figura
plt.tight_layout()
plt.show()

# %%
# categorical values
n_classes = len(set(y_dataset))
print(n_classes)

y_dataset_ = to_categorical(y_dataset, n_classes)
# Out:
# 2

# %%
# Ajusta o tamanho do dataset para coincidir com o tamanho menor entre dataset_trimmed e y_dataset_
min_length = min(len(dataset), len(y_dataset_))
dataset_trimmed = dataset[:min_length]
y_dataset_trimmed = y_dataset_[:min_length]

# Verifica se os tamanhos agora estão iguais
assert len(dataset_trimmed) == len(y_dataset_trimmed), "Os tamanhos ainda não são consistentes!"

# Dividindo em conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(dataset_trimmed, y_dataset_trimmed, test_size=0.2)

print("Train set size: {}, Test set size: {}".format(len(X_train), len(X_test)))
# Out:
# Train set size: 1879, Test set size: 470

# %%
from sklearn.utils import resample

# Criar listas vazias para armazenar as amostras balanceadas
balanced_X_train = []
balanced_y_train = []

# Determinar o número de amostras na classe majoritária
majority_samples = 9000

# Iterar sobre cada classe
for class_label in np.unique(y_train.argmax(axis=1)):
    # Filtrar amostras pertencentes a essa classe
    X_class = X_train[y_train.argmax(axis=1) == class_label]
    y_class = y_train[y_train.argmax(axis=1) == class_label]

    # Calcular o número de amostras na classe menos representada
    minority_samples = len(X_class)

    # Balancear as amostras aumentando a classe menos representada
    balanced_X_class, balanced_y_class = resample(X_class, y_class,
                                                  replace=True,
                                                  n_samples=majority_samples,
                                                  random_state=42)

    # Adicionar amostras balanceadas à lista
    balanced_X_train.extend(balanced_X_class)
    balanced_y_train.extend(balanced_y_class)

# Converter listas em arrays numpy
balanced_X_train = np.array(balanced_X_train)
balanced_y_train = np.array(balanced_y_train)

# Embaralhar amostras
shuffled_indices = np.arange(len(balanced_X_train))
np.random.shuffle(shuffled_indices)
balanced_X_train = balanced_X_train[shuffled_indices]
balanced_y_train = balanced_y_train[shuffled_indices]

# Verificar o tamanho dos conjuntos de dados balanceados
print("Tamanho do conjunto de treinamento balanceado:", len(balanced_X_train))
print("Tamanho do conjunto de teste:", len(X_test))

for class_label in np.unique(balanced_y_train.argmax(axis=1)):
    count = np.sum(balanced_y_train.argmax(axis=1) == class_label)
    print(f"Classe {class_label}: {count} amostras")
# Out:
# Tamanho do conjunto de treinamento balanceado: 18000
# Tamanho do conjunto de teste: 470
# Classe 0: 9000 amostras
# Classe 1: 9000 amostras

# %%
# Criar o modelo
model = Sequential()

model.add(BatchNormalization(input_shape=(image_height, image_width, 3)))
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))  # Adiciona a camada de dropout
model.add(Dense(2, activation='softmax'))  # Especifica 'softmax' como a função de ativação

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ batch_normalization                  │ (None, 48, 48, 3)           │              12 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 48, 48, 512)         │          14,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 24, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 24, 24, 256)         │       1,179,904 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 36864)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │       1,179,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,373,998 (9.06 MB)
#  Trainable params: 2,373,992 (9.06 MB)
#  Non-trainable params: 6 (24.00 B)

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Treinando o modelo
from tensorflow.keras.callbacks import EarlyStopping

# Configurar EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=15)

# Treinar o modelo
history = model.fit(balanced_X_train, balanced_y_train,validation_split= 0.2, epochs=100, callbacks=[early_stopping], batch_size=64)
# Out:
# Epoch 1/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 25s 71ms/step - accuracy: 0.8618 - loss: 0.3340 - val_accuracy: 0.9089 - val_loss: 0.2260
# Epoch 2/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 31s 59ms/step - accuracy: 0.9910 - loss: 0.0259 - val_accuracy: 0.9986 - val_loss: 0.0083
# Epoch 3/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 60ms/step - accuracy: 0.9935 - loss: 0.0203 - val_accuracy: 1.0000 - val_loss: 9.2831e-04
# Epoch 4/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9997 - val_loss: 4.9979e-04
# Epoch 5/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9985 - loss: 0.0051 - val_accuracy: 0.9903 - val_loss: 0.0253
# Epoch 6/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9931 - loss: 0.0198 - val_accuracy: 0.9997 - val_loss: 6.7548e-04
# Epoch 7/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9997 - val_loss: 0.0015
# Epoch 8/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 14s 60ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 1.8791e-04
# Epoch 9/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9958 - loss: 0.0137 - val_accuracy: 0.9986 - val_loss: 0.0040
# Epoch 10/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.9988 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 4.8152e-05
# Epoch 11/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9997 - val_loss: 8.7214e-04
# Epoch 12/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 1.0000 - loss: 5.9389e-04 - val_accuracy: 0.9997 - val_loss: 4.2406e-04
# Epoch 13/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.9985 - loss: 0.0052 - val_accuracy: 0.9944 - val_loss: 0.0209
# Epoch 14/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9944 - loss: 0.0224 - val_accuracy: 0.9972 - val_loss: 0.0067
# Epoch 15/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.9964 - loss: 0.0088 - val_accuracy: 0.9997 - val_loss: 0.0016
# Epoch 16/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 0.9978 - loss: 0.0051 - val_accuracy: 0.9997 - val_loss: 0.0016
# Epoch 17/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9992 - val_loss: 0.0034
# Epoch 18/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.9983 - val_loss: 0.0096
# Epoch 19/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.9980 - loss: 0.0069 - val_accuracy: 0.9997 - val_loss: 0.0011
# Epoch 20/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9941 - loss: 0.0224 - val_accuracy: 0.9997 - val_loss: 6.4448e-04
# Epoch 21/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.9994 - loss: 0.0028 - val_accuracy: 0.9997 - val_loss: 0.0012
# Epoch 22/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.9992 - loss: 0.0027 - val_accuracy: 0.9992 - val_loss: 0.0015
# Epoch 23/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.9994 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 1.9580e-04
# Epoch 24/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 59ms/step - accuracy: 0.9996 - loss: 0.0021 - val_accuracy: 0.9992 - val_loss: 0.0070
# Epoch 25/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - accuracy: 0.9972 - loss: 0.0117 - val_accuracy: 0.9994 - val_loss: 0.0018

# %%
val_accuracy = history.history['val_accuracy']

mean_val_accuracy = np.mean(val_accuracy)

print("Valor médio de acurácia:", mean_val_accuracy)
# Out:
# Valor médio de acurácia: 0.9952222275733947

# %%
import pandas as pd
history_save = pd.DataFrame(history.history)
history_save.to_csv('datasetCAI.csv')

# %%
# save model structure in jason file
model_json = model.to_json()
with open("CAImodel.json", "w") as json_file:
    json_file.write(model_json)

# %%
model.save('modeloCAI.keras')

# %%
from keras.models import load_model

modelo_carregado = load_model('/content/modeloCAI.keras')

# %%
import pandas as pd

history = pd.read_csv('/content/datasetCAI.csv')

# %%
import matplotlib.pyplot as plt

plt.plot(history['loss'])
plt.plot(history['val_loss'])


plt.ylabel('Perda')
plt.xlabel('Época')
plt.legend(['Treinamento', 'Validação'], loc = 'upper right')
plt.show()

# %%
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Acurácia')
plt.ylabel('Acurácia')
plt.xlabel('Épocas')
plt.legend(['Treinamento', 'Validação'], loc='upper left')
plt.grid(True)
plt.show()
plt.close()

# %%
preds = modelo_carregado.predict(X_test)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step

# %%
#Função da Matriz de Confusão

def plot_confusion_matrix(
        cm,
        classes,
        normalize=False,
        title='Confusion matrix',
        cmap=plt.cm.Blues
    ):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    #plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
#Gráfico da Matriz de Confusão

y_test_ = [np.argmax(x) for x in y_test]
preds_ = [np.argmax(x) for x in preds]

cm = confusion_matrix(y_test_, preds_)
plot_confusion_matrix(cm, classes=['Positive', 'Negative Positive'], title='Confusion matrix')
plt.show()
plt.close()
# Out:
# Confusion matrix, without normalization
# [[ 47   1]
#  [  5 417]]

# %%
#Resultado das predições

n = 4
for t in range(4):
    plt.figure(figsize=(10,10))
    for i in range(n*t, n*(t+1)):
        plt.subplot(1, n, i + 1 - n*t)
        plt.imshow(cv2.cvtColor(X_test[i], cv2.COLOR_BGR2RGB), cmap='gray')
        plt.title('Real: {}\nPredito: {}'.format(classes[np.argmax(y_test[i])], classes[np.argmax(preds[i])]))
        plt.axis('off')
    plt.show()

# %%
from keras.models import load_model

modelo = load_model("modeloCAI.keras")  # Ajuste o caminho se necessário

# %%
print(modelo.input_shape)
# Out:
# (None, 48, 48, 3)

# %%
import cv2

def preprocessar_imagem(caminho):
    imagem = cv2.imread(caminho)  # Carregar imagem
    imagem = cv2.resize(imagem, (48, 48))  # Redimensionar para 48x48 pixels
    imagem = imagem.astype("float32") / 255.0  # Normalizar os valores para [0,1]
    imagem = np.expand_dims(imagem, axis=0)  # Adicionar dimensão do batch
    return imagem

# %%
import os
import numpy as np
import cv2
import tensorflow as tf

# Desativar logs do TensorFlow
tf.get_logger().setLevel('ERROR')

pasta_imagens = "/content/drive/Shareddrives/Letícia Vieira Gonçalves - Pesquisa/dataset/CAI-SWTB-Dataset/Test/Test/Validation/Healthy"
valid_extensions = (".jpg", ".jpeg", ".png", ".bmp")

# Mapeamento das classes
mapping = {0: "Faulty", 1: "Healthy"}

# Inicializar contadores
classificacao_certa = 0
classificacao_errada = 0

def preprocessar_imagem(caminho):
    imagem = cv2.imread(caminho)  # Carregar imagem
    if imagem is None:
        return None
    imagem = cv2.resize(imagem, (48, 48))  # Redimensionar para 48x48 pixels
    imagem = imagem.astype("float32") / 255.0  # Normalizar os valores para [0,1]
    imagem = np.expand_dims(imagem, axis=0)  # Adicionar dimensão do batch
    return imagem

# Certificar que o modelo está definido
try:
    modelo  # Verifica se a variável modelo está definida
except NameError:
    raise ValueError("O modelo não foi carregado corretamente. Certifique-se de inicializá-lo antes de executar o script.")

# Percorrer todas as imagens da pasta
for nome_arquivo in os.listdir(pasta_imagens):
    if nome_arquivo.lower().endswith(valid_extensions):  # Verifica se é uma imagem
        caminho_imagem = os.path.join(pasta_imagens, nome_arquivo)

        # Pré-processar a imagem
        imagem = preprocessar_imagem(caminho_imagem)

        if imagem is None:
            continue

        # Fazer a predição sem logs
        predicao = modelo.predict(imagem, verbose=0)
        if predicao is None or not hasattr(predicao, 'shape'):
            continue

        classe_predita = np.argmax(predicao)  # Obtém a classe com maior probabilidade
        classe_predita_nome = mapping.get(classe_predita, "Desconhecido")

        # Contador para classificações
        if "Healthy" in nome_arquivo and classe_predita_nome == "Healthy":
            classificacao_certa += 1
        elif "Faulty" in nome_arquivo and classe_predita_nome == "Faulty":
            classificacao_certa += 1
        else:
            classificacao_errada += 1

print(f"Total de Classificações Corretas: {classificacao_certa}")
print(f"Total de Classificações Erradas: {classificacao_errada}")
# Out:
# Total de Classificações Corretas: 289
# Total de Classificações Erradas: 11

# %% [markdown]
# =============================================

# %% [markdown]
# U-Net

# %%
import os
import cv2
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder='/content/drive/Shareddrives/Leticia_Vieira_G_Pesquisa/dataset/CAI-SWTB-Dataset/test'

# %%
input_folder = "/content/drive/Shareddrives/Leticia_Vieira_G_Pesquisa/dataset/CAI-SWTB-Dataset/test/Faulty"
output_folder = "/content/drive/Shareddrives/Leticia_Vieira_G_Pesquisa/dataset/CAI-SWTB-Dataset/test/segmentadas_faulty"

# Criar a pasta de saída se não existir
os.makedirs(output_folder, exist_ok=True)

# Processar todas as imagens na pasta de entrada
for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):  # Filtrar imagens
        image_path = os.path.join(input_folder, filename)

        # Carregar imagem
        image = cv2.imread(image_path)
        if image is None:
            continue  # Ignorar arquivos inválidos

        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Redimensionar para manter o desempenho
        image_resized = cv2.resize(image, (image.shape[1] // 1, image.shape[0] // 1))

        # Converter para o formato adequado para clustering
        image_data = image_resized.reshape((-1, 1))

        # Aplicar K-means clustering
        kmeans = KMeans(n_clusters=2, random_state=256, n_init=10)
        kmeans.fit(image_data)

        # Criar a máscara binária
        mask = kmeans.labels_.reshape(image_resized.shape[:2])

        # Salvar a máscara como imagem
        output_path = os.path.join(output_folder, f"segmented_{filename}")
        cv2.imwrite(output_path, (mask * 255).astype(np.uint8))

print("Processamento concluído! As imagens segmentadas foram salvas.")
# Out:
# Processamento concluído! As imagens segmentadas foram salvas.

# %%
input_folder = "/content/drive/Shareddrives/Leticia_Vieira_G_Pesquisa/dataset/CAI-SWTB-Dataset/test/Healthy"
output_folder = "/content/drive/Shareddrives/Leticia_Vieira_G_Pesquisa/dataset/CAI-SWTB-Dataset/test/segmentadas_healthy"

# Criar a pasta de saída se não existir
os.makedirs(output_folder, exist_ok=True)

# Processar todas as imagens na pasta de entrada
for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):  # Filtrar imagens
        image_path = os.path.join(input_folder, filename)

        # Carregar imagem
        image = cv2.imread(image_path)
        if image is None:
            continue  # Ignorar arquivos inválidos

        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Redimensionar para manter o desempenho
        image_resized = cv2.resize(image, (image.shape[1] // 1, image.shape[0] // 1))

        # Converter para o formato adequado para clustering
        image_data = image_resized.reshape((-1, 1))

        # Aplicar K-means clustering
        kmeans = KMeans(n_clusters=2, random_state=256, n_init=10)
        kmeans.fit(image_data)

        # Criar a máscara binária
        mask = kmeans.labels_.reshape(image_resized.shape[:2])

        # Salvar a máscara como imagem
        output_path = os.path.join(output_folder, f"segmented_{filename}")
        cv2.imwrite(output_path, (mask * 255).astype(np.uint8))

print("Processamento concluído! As imagens segmentadas foram salvas.")
# Out:
# Processamento concluído! As imagens segmentadas foram salvas.

# %% [markdown]
# CNN - Treino com o uso das imagens segmentadas pelo U-Net

# %%
import cv2
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization, Activation, Add, Input, AveragePooling2D
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import regularizers

import numpy as np
import os, sys
from scipy import ndimage
import cv2
import matplotlib.pyplot as plt
import itertools
import scipy.stats
import tensorflow as tf
from keras import applications, optimizers, Input
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils.multiclass import unique_labels

# %%
#image resolution
image_width = 48
image_height = 48
channels = 3 #rgb

train_files = []
i=0
for classes in ['segmentadas_faulty', 'segmentadas_healthy']:
    print(os.path.join(folder, classes))
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes)) if os.path.isfile(os.path.join(folder, classes, f ))]
    for _file in onlyfiles:
        train_files.append(_file)

dataset = np.ndarray(shape=(len(train_files), image_height, image_width, channels),
                     dtype=np.float32)
y_dataset = []
# Out:
# /content/drive/Shareddrives/Leticia_Vieira_G_Pesquisa/dataset/CAI-SWTB-Dataset/test/segmentadas_faulty
# /content/drive/Shareddrives/Leticia_Vieira_G_Pesquisa/dataset/CAI-SWTB-Dataset/test/segmentadas_healthy

# %%
i = 0

valid_extensions=(".jpg", ".jpeg", ".png", ".bmp")

for classes in ['segmentadas_faulty', 'segmentadas_healthy']: #catregorias das imagens
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes))
     if f.lower().endswith(valid_extensions) and
             os.path.isfile(os.path.join(folder, classes, f))]

    #if os.path.isfile(os.path.join(folder, classes, f))] #seleciona as imagens e ignora pastas
    for _file in onlyfiles: #Percorre os arquivos da pasta
        img_path = os.path.join(folder, classes, _file)
        img = load_img(img_path, target_size=(image_height, image_width)) #redimenciona a iamgem
        x = img_to_array(img)

        dataset[i] = x #armazenando os dados
        mapping = {'segmentadas_faulty': 0 , 'segmentadas_healthy': 1} #dicionario
        y_dataset.append(mapping[classes])  #rotulo das imagens

        i += 1
        if i == 30000:
            print("%d images to array" % i)
            break

print("All images to array!")
# Out:
# All images to array!

# %%
#Normalização
dataset = dataset.astype('float32')
dataset /= 255

# %%
classes = ['Faulty', 'Healthy']

# Dicionário para armazenar o índice da primeira imagem de cada classe
first_image_index = {}

# Encontra o índice da primeira imagem de cada classe
for i, label in enumerate(y_dataset):
    if label not in first_image_index:
        first_image_index[label] = i

# Configura a grade para exibir as imagens
num_classes = len(set(y_dataset))
num_images_per_class = 1
num_cols = num_classes
num_rows = num_images_per_class

# %%
# Cria uma figura com uma grade de subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(5, 15))

# Loop através de cada classe
for i in range(num_classes):
    # Obtém o índice da primeira imagem da classe
    idx = first_image_index[i]

    # Obtém a imagem e converte para RGB
    pixels = dataset[idx]

    # Exibe a imagem no subplot correspondente
    axes[i].imshow(pixels, cmap='Spectral')
    axes[i].axis('off')

    # Adiciona um título para o subplot com o rótulo
    axes[i].set_title(f'{classes[i]}')

# Exibe a figura
plt.tight_layout()
plt.show()

# %%
# categorical values
n_classes = len(set(y_dataset))
print(n_classes)

y_dataset_ = to_categorical(y_dataset, n_classes)
# Out:
# 2

# %%
# Ajusta o tamanho do dataset para coincidir com o tamanho menor entre dataset_trimmed e y_dataset_
min_length = min(len(dataset), len(y_dataset_))
dataset_trimmed = dataset[:min_length]
y_dataset_trimmed = y_dataset_[:min_length]

# Verifica se os tamanhos agora estão iguais
assert len(dataset_trimmed) == len(y_dataset_trimmed), "Os tamanhos ainda não são consistentes!"

# Dividindo em conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(dataset_trimmed, y_dataset_trimmed, test_size=0.2)

print("Train set size: {}, Test set size: {}".format(len(X_train), len(X_test)))
# Out:
# Train set size: 960, Test set size: 240

# %%
from sklearn.utils import resample

# Criar listas vazias para armazenar as amostras balanceadas
balanced_X_train = []
balanced_y_train = []

# Determinar o número de amostras na classe majoritária
majority_samples = 5000

# Iterar sobre cada classe
for class_label in np.unique(y_train.argmax(axis=1)):
    # Filtrar amostras pertencentes a essa classe
    X_class = X_train[y_train.argmax(axis=1) == class_label]
    y_class = y_train[y_train.argmax(axis=1) == class_label]

    # Calcular o número de amostras na classe menos representada
    minority_samples = len(X_class)

    # Balancear as amostras aumentando a classe menos representada
    balanced_X_class, balanced_y_class = resample(X_class, y_class,
                                                  replace=True,
                                                  n_samples=majority_samples,
                                                  random_state=42)

    # Adicionar amostras balanceadas à lista
    balanced_X_train.extend(balanced_X_class)
    balanced_y_train.extend(balanced_y_class)

# Converter listas em arrays numpy
balanced_X_train = np.array(balanced_X_train)
balanced_y_train = np.array(balanced_y_train)

# Embaralhar amostras
shuffled_indices = np.arange(len(balanced_X_train))
np.random.shuffle(shuffled_indices)
balanced_X_train = balanced_X_train[shuffled_indices]
balanced_y_train = balanced_y_train[shuffled_indices]

# Verificar o tamanho dos conjuntos de dados balanceados
print("Tamanho do conjunto de treinamento balanceado:", len(balanced_X_train))
print("Tamanho do conjunto de teste:", len(X_test))

for class_label in np.unique(balanced_y_train.argmax(axis=1)):
    count = np.sum(balanced_y_train.argmax(axis=1) == class_label)
    print(f"Classe {class_label}: {count} amostras")
# Out:
# Tamanho do conjunto de treinamento balanceado: 10000
# Tamanho do conjunto de teste: 240
# Classe 0: 5000 amostras
# Classe 1: 5000 amostras

# %%
# Criar o modelo
model = Sequential()

model.add(BatchNormalization(input_shape=(image_height, image_width, 3)))
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))  # Adiciona a camada de dropout
model.add(Dense(2, activation='softmax'))  # Especifica 'softmax' como a função de ativação

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization             │ (None, 48, 48, 3)      │            12 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 48, 48, 512)    │        14,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 36864)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │     1,179,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,373,998 (9.06 MB)
#  Trainable params: 2,373,992 (9.06 MB)
#  Non-trainable params: 6 (24.00 B)

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Treinando o modelo
from tensorflow.keras.callbacks import EarlyStopping

# Configurar EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=20)

# Treinar o modelo
history = model.fit(balanced_X_train, balanced_y_train,validation_split= 0.2, epochs=100, callbacks=[early_stopping], batch_size=64)
# Out:
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.5146 - loss: 0.8023 - val_accuracy: 0.6665 - val_loss: 0.6332
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.6708 - loss: 0.5954 - val_accuracy: 0.8035 - val_loss: 0.4721
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.7757 - loss: 0.4628 - val_accuracy: 0.9055 - val_loss: 0.2829
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.8710 - loss: 0.2996 - val_accuracy: 0.9650 - val_loss: 0.1461
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - accuracy: 0.9201 - loss: 0.2079 - val_accuracy: 0.9795 - val_loss: 0.0947
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9390 - loss: 0.1536 - val_accuracy: 0.9875 - val_loss: 0.0574
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9470 - loss: 0.1388 - val_accuracy: 0.9890 - val_loss: 0.0434
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9501 - loss: 0.1214 - val_accuracy: 0.9925 - val_loss: 0.0268
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9573 - loss: 0.1135 - val_accuracy: 0.9985 - val_loss: 0.0159
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.9626 - loss: 0.0935 - val_accuracy: 0.9955 - val_loss: 0.0205
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.9702 - loss: 0.0801 - val_accuracy: 0.9965 - val_loss: 0.0146
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.9720 - loss: 0.0779 - val_accuracy: 0.9970 - val_loss: 0.0144
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.9717 - loss: 0.0765 - val_accuracy: 0.9985 - val_loss: 0.0083
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.9779 - loss: 0.0633 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 15/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.9737 - loss: 0.0743 - val_accuracy: 0.9985 - val_loss: 0.0091
# Epoch 16/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9717 - loss: 0.0725 - val_accuracy: 0.9980 - val_loss: 0.0087
# Epoch 17/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.9762 - loss: 0.0669 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 18/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.9757 - loss: 0.0571 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 19/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.9795 - loss: 0.0578 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 20/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.9781 - loss: 0.0599 - val_accuracy: 0.9960 - val_loss: 0.0106
# Epoch 21/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.9768 - loss: 0.0675 - val_accuracy: 0.9970 - val_loss: 0.0070
# Epoch 22/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.9826 - loss: 0.0505 - val_accuracy: 0.9985 - val_loss: 0.0049
# Epoch 23/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.9764 - loss: 0.0608 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 24/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9824 - loss: 0.0431 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 25/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9832 - loss: 0.0483 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 26/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9840 - loss: 0.0484 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 27/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.9838 - loss: 0.0471 - val_accuracy: 0.9995 - val_loss: 0.0026
# Epoch 28/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9832 - loss: 0.0466 - val_accuracy: 0.9985 - val_loss: 0.0041
# Epoch 29/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9861 - loss: 0.0359 - val_accuracy: 0.9985 - val_loss: 0.0044
# Epoch 30/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9878 - loss: 0.0360 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 31/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9843 - loss: 0.0449 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 32/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.9830 - loss: 0.0412 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 33/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9799 - loss: 0.0498 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 34/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9823 - loss: 0.0479 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 35/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9835 - loss: 0.0416 - val_accuracy: 0.9985 - val_loss: 0.0028
# Epoch 36/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.9871 - loss: 0.0437 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 37/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9834 - loss: 0.0417 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 38/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9811 - loss: 0.0511 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 39/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9834 - loss: 0.0436 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 40/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9863 - loss: 0.0362 - val_accuracy: 1.0000 - val_loss: 8.9464e-04
# Epoch 41/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9851 - loss: 0.0455 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 42/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9852 - loss: 0.0488 - val_accuracy: 1.0000 - val_loss: 7.2251e-04
# Epoch 43/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9872 - loss: 0.0348 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 44/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9850 - loss: 0.0422 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 45/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9861 - loss: 0.0408 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 46/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9851 - loss: 0.0420 - val_accuracy: 1.0000 - val_loss: 6.8612e-04
# Epoch 47/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9886 - loss: 0.0324 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 48/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9883 - loss: 0.0315 - val_accuracy: 0.9985 - val_loss: 0.0034
# Epoch 49/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9872 - loss: 0.0382 - val_accuracy: 1.0000 - val_loss: 8.1989e-04
# Epoch 50/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9890 - loss: 0.0292 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 51/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9898 - loss: 0.0304 - val_accuracy: 1.0000 - val_loss: 9.2616e-04
# Epoch 52/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9864 - loss: 0.0359 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 53/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.9853 - loss: 0.0350 - val_accuracy: 1.0000 - val_loss: 7.9807e-04
# Epoch 54/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9870 - loss: 0.0362 - val_accuracy: 1.0000 - val_loss: 7.7080e-04
# Epoch 55/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.9861 - loss: 0.0352 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 56/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9884 - loss: 0.0327 - val_accuracy: 1.0000 - val_loss: 7.6890e-04
# Epoch 57/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9880 - loss: 0.0319 - val_accuracy: 1.0000 - val_loss: 5.5123e-04
# Epoch 58/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9886 - loss: 0.0282 - val_accuracy: 1.0000 - val_loss: 6.7506e-04
# Epoch 59/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.9891 - loss: 0.0298 - val_accuracy: 1.0000 - val_loss: 7.2615e-04
# Epoch 60/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9878 - loss: 0.0345 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 61/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9919 - loss: 0.0275 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 62/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9891 - loss: 0.0325 - val_accuracy: 1.0000 - val_loss: 5.7454e-04
# Epoch 63/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.9872 - loss: 0.0348 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 64/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9873 - loss: 0.0327 - val_accuracy: 0.9985 - val_loss: 0.0015
# Epoch 65/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9880 - loss: 0.0389 - val_accuracy: 1.0000 - val_loss: 9.7131e-04
# Epoch 66/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.9886 - loss: 0.0296 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 67/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9904 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 68/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9923 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 8.1350e-04
# Epoch 69/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9896 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 70/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9884 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 6.1793e-04
# Epoch 71/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9868 - loss: 0.0312 - val_accuracy: 1.0000 - val_loss: 4.1072e-04
# Epoch 72/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9900 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 4.6978e-04
# Epoch 73/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.9889 - loss: 0.0296 - val_accuracy: 1.0000 - val_loss: 5.6509e-04
# Epoch 74/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9872 - loss: 0.0340 - val_accuracy: 1.0000 - val_loss: 7.6130e-04
# Epoch 75/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9916 - loss: 0.0274 - val_accuracy: 1.0000 - val_loss: 7.9122e-04
# Epoch 76/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9908 - loss: 0.0220 - val_accuracy: 0.9985 - val_loss: 0.0020
# Epoch 77/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9881 - loss: 0.0294 - val_accuracy: 1.0000 - val_loss: 4.2383e-04
# Epoch 78/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9903 - loss: 0.0284 - val_accuracy: 1.0000 - val_loss: 6.7766e-04
# Epoch 79/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.9919 - loss: 0.0203 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 80/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9892 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 7.3013e-04
# Epoch 81/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9886 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 6.5473e-04
# Epoch 82/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.9922 - loss: 0.0220 - val_accuracy: 1.0000 - val_loss: 4.1292e-04
# Epoch 83/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9886 - loss: 0.0326 - val_accuracy: 1.0000 - val_loss: 6.9495e-04
# Epoch 84/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9913 - loss: 0.0254 - val_accuracy: 1.0000 - val_loss: 4.4227e-04
# Epoch 85/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9926 - loss: 0.0254 - val_accuracy: 1.0000 - val_loss: 3.0411e-04
# Epoch 86/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.9919 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 5.7282e-04
# Epoch 87/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9925 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 8.0543e-04
# Epoch 88/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9895 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 2.4496e-04
# Epoch 89/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9898 - loss: 0.0297 - val_accuracy: 1.0000 - val_loss: 5.8772e-04
# Epoch 90/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9926 - loss: 0.0219 - val_accuracy: 1.0000 - val_loss: 5.8326e-04
# Epoch 91/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.9904 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 3.2479e-04
# Epoch 92/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9907 - loss: 0.0299 - val_accuracy: 1.0000 - val_loss: 9.0039e-04
# Epoch 93/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.9916 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 3.7470e-04
# Epoch 94/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9941 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 2.6715e-04
# Epoch 95/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9887 - loss: 0.0320 - val_accuracy: 1.0000 - val_loss: 5.2980e-04
# Epoch 96/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9918 - loss: 0.0241 - val_accuracy: 1.0000 - val_loss: 8.1188e-04
# Epoch 97/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9895 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 4.6453e-04
# Epoch 98/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.9899 - loss: 0.0301 - val_accuracy: 1.0000 - val_loss: 3.4758e-04
# Epoch 99/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.9931 - loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 3.8897e-04
# Epoch 100/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9907 - loss: 0.0219 - val_accuracy: 1.0000 - val_loss: 2.0904e-04

# %%
val_accuracy = history.history['val_accuracy']

mean_val_accuracy = np.mean(val_accuracy)

print("Valor médio de acurácia:", mean_val_accuracy)
# Out:
# Valor médio de acurácia: 0.9925349986553192

# %% [markdown]
# Carregamento do modelo

# %%
import pandas as pd
history_save = pd.DataFrame(history.history)
history_save.to_csv('datasetCAI2.csv')

# %%
# save model structure in jason file
model_json = model.to_json()
with open("CAImodel.json", "w") as json_file:
    json_file.write(model_json)

# %%
model.save('modeloCAI2.keras')

# %%
from keras.models import load_model

modelo_carregado = load_model('/content/modeloCAI2.keras')

# %%
import pandas as pd

history = pd.read_csv('/content/datasetCAI2.csv')

# %% [markdown]
# Plotando o modelo

# %%
import matplotlib.pyplot as plt

plt.plot(history['loss'])
plt.plot(history['val_loss'])


plt.ylabel('Perda')
plt.xlabel('Época')
plt.legend(['Treinamento', 'Validação'], loc = 'upper right')
plt.show()

# %%
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Acurácia')
plt.ylabel('Acurácia')
plt.xlabel('Épocas')
plt.legend(['Treinamento', 'Validação'], loc='upper left')
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# Salvando o modelo

# %%
preds = modelo_carregado.predict(X_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step

# %%
#Função da Matriz de Confusão

def plot_confusion_matrix(
        cm,
        classes,
        normalize=False,
        title='Confusion matrix',
        cmap=plt.cm.Blues
    ):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    #plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
#Gráfico da Matriz de Confusão

y_test_ = [np.argmax(x) for x in y_test]
preds_ = [np.argmax(x) for x in preds]

cm = confusion_matrix(y_test_, preds_)
plot_confusion_matrix(cm, classes=['Positive', 'Negative Positive'], title='Confusion matrix')
plt.show()
plt.close()
# Out:
# Confusion matrix, without normalization
# [[73 54]
#  [35 78]]

# %%
#Resultado das predições

n = 4
for t in range(4):
    plt.figure(figsize=(10,10))
    for i in range(n*t, n*(t+1)):
        plt.subplot(1, n, i + 1 - n*t)
        plt.imshow(cv2.cvtColor(X_test[i], cv2.COLOR_BGR2RGB), cmap='gray')
        plt.title('Real: {}\nPredito: {}'.format(classes[np.argmax(y_test[i])], classes[np.argmax(preds[i])]))
        plt.axis('off')
    plt.show()
