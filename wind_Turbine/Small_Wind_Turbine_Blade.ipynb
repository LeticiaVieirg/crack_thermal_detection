# %% [markdown]
# <a href="https://colab.research.google.com/github/LeticiaVieirg/crack_thermal_detection/blob/main/Thermal_Cracks_and_Others_Cracks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Importação das bibliotecas

# %%
import cv2
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization, Activation, Add, Input, AveragePooling2D
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import regularizers

import numpy as np
import os, sys
from scipy import ndimage
import cv2
import matplotlib.pyplot as plt
import itertools
import scipy.stats
import tensorflow as tf
from keras import applications, optimizers, Input
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils.multiclass import unique_labels

# %% [markdown]
# 2. Carregando o dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder='/content/drive/Shareddrives/Letícia Vieira Gonçalves - Pesquisa/dataset/CAI-SWTB-Dataset/Train'

# %% [markdown]
# 3. Estruturando o dataset

# %%
#image resolution
image_width = 48
image_height = 48
channels = 3 #rgb

train_files = []
i=0
for classes in ['Faulty', 'Healthy']:
    print(os.path.join(folder, classes))
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes)) if os.path.isfile(os.path.join(folder, classes, f ))]
    for _file in onlyfiles:
        train_files.append(_file)

dataset = np.ndarray(shape=(len(train_files), image_height, image_width, channels),
                     dtype=np.float32)
y_dataset = []
# Out:
# /content/drive/Shareddrives/Letícia Vieira Gonçalves - Pesquisa/dataset/CAI-SWTB-Dataset/Train/Faulty
# /content/drive/Shareddrives/Letícia Vieira Gonçalves - Pesquisa/dataset/CAI-SWTB-Dataset/Train/Healthy

# %%
i = 0

valid_extensions=(".jpg", ".jpeg", ".png", ".bmp")

for classes in ['Faulty', 'Healthy']: #catregorias das imagens
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes))
     if f.lower().endswith(valid_extensions) and
             os.path.isfile(os.path.join(folder, classes, f))]

    #if os.path.isfile(os.path.join(folder, classes, f))] #seleciona as imagens e ignora pastas
    for _file in onlyfiles: #Percorre os arquivos da pasta
        img_path = os.path.join(folder, classes, _file)
        img = load_img(img_path, target_size=(image_height, image_width)) #redimenciona a iamgem
        x = img_to_array(img)

        dataset[i] = x #armazenando os dados
        mapping = {'Faulty': 0 , 'Healthy': 1} #dicionario
        y_dataset.append(mapping[classes])  #rotulo das imagens

        i += 1
        if i == 30000:
            print("%d images to array" % i)
            break

print("All images to array!")
# Out:
# All images to array!

# %% [markdown]
# 6. Normalizando os dados

# %%
#Normalização
dataset = dataset.astype('float32')
dataset /= 255

# %%
classes = ['Faulty', 'Healthy']

# Dicionário para armazenar o índice da primeira imagem de cada classe
first_image_index = {}

# Encontra o índice da primeira imagem de cada classe
for i, label in enumerate(y_dataset):
    if label not in first_image_index:
        first_image_index[label] = i

# Configura a grade para exibir as imagens
num_classes = len(set(y_dataset))
num_images_per_class = 1
num_cols = num_classes
num_rows = num_images_per_class

# %%
# Cria uma figura com uma grade de subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(5, 15))

# Loop através de cada classe
for i in range(num_classes):
    # Obtém o índice da primeira imagem da classe
    idx = first_image_index[i]

    # Obtém a imagem e converte para RGB
    pixels = dataset[idx]

    # Exibe a imagem no subplot correspondente
    axes[i].imshow(pixels, cmap='Spectral')
    axes[i].axis('off')

    # Adiciona um título para o subplot com o rótulo
    axes[i].set_title(f'{classes[i]}')

# Exibe a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# 7. Normalizando o dataset

# %%
# categorical values
n_classes = len(set(y_dataset))
print(n_classes)

y_dataset_ = to_categorical(y_dataset, n_classes)
# Out:
# 2

# %%
# Ajusta o tamanho do dataset para coincidir com o tamanho menor entre dataset_trimmed e y_dataset_
min_length = min(len(dataset), len(y_dataset_))
dataset_trimmed = dataset[:min_length]
y_dataset_trimmed = y_dataset_[:min_length]

# Verifica se os tamanhos agora estão iguais
assert len(dataset_trimmed) == len(y_dataset_trimmed), "Os tamanhos ainda não são consistentes!"

# Dividindo em conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(dataset_trimmed, y_dataset_trimmed, test_size=0.2)

print("Train set size: {}, Test set size: {}".format(len(X_train), len(X_test)))
# Out:
# Train set size: 1879, Test set size: 470

# %%
from sklearn.utils import resample

# Criar listas vazias para armazenar as amostras balanceadas
balanced_X_train = []
balanced_y_train = []

# Determinar o número de amostras na classe majoritária
majority_samples = 2000

# Iterar sobre cada classe
for class_label in np.unique(y_train.argmax(axis=1)):
    # Filtrar amostras pertencentes a essa classe
    X_class = X_train[y_train.argmax(axis=1) == class_label]
    y_class = y_train[y_train.argmax(axis=1) == class_label]

    # Calcular o número de amostras na classe menos representada
    minority_samples = len(X_class)

    # Balancear as amostras aumentando a classe menos representada
    balanced_X_class, balanced_y_class = resample(X_class, y_class,
                                                  replace=True,
                                                  n_samples=majority_samples,
                                                  random_state=42)

    # Adicionar amostras balanceadas à lista
    balanced_X_train.extend(balanced_X_class)
    balanced_y_train.extend(balanced_y_class)

# Converter listas em arrays numpy
balanced_X_train = np.array(balanced_X_train)
balanced_y_train = np.array(balanced_y_train)

# Embaralhar amostras
shuffled_indices = np.arange(len(balanced_X_train))
np.random.shuffle(shuffled_indices)
balanced_X_train = balanced_X_train[shuffled_indices]
balanced_y_train = balanced_y_train[shuffled_indices]

# Verificar o tamanho dos conjuntos de dados balanceados
print("Tamanho do conjunto de treinamento balanceado:", len(balanced_X_train))
print("Tamanho do conjunto de teste:", len(X_test))

for class_label in np.unique(balanced_y_train.argmax(axis=1)):
    count = np.sum(balanced_y_train.argmax(axis=1) == class_label)
    print(f"Classe {class_label}: {count} amostras")
# Out:
# Tamanho do conjunto de treinamento balanceado: 4000
# Tamanho do conjunto de teste: 470
# Classe 0: 2000 amostras
# Classe 1: 2000 amostras

# %%
# Criar o modelo
model = Sequential()

model.add(BatchNormalization(input_shape=(image_height, image_width, 3)))
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))  # Adiciona a camada de dropout
model.add(Dense(2, activation='softmax'))  # Especifica 'softmax' como a função de ativação

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ batch_normalization                  │ (None, 48, 48, 3)           │              12 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 48, 48, 512)         │          14,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 24, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 24, 24, 256)         │       1,179,904 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 36864)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │       1,179,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,373,998 (9.06 MB)
#  Trainable params: 2,373,992 (9.06 MB)
#  Non-trainable params: 6 (24.00 B)

# %% [markdown]
# 4. Compilando o modelo

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Treinando o modelo
from tensorflow.keras.callbacks import EarlyStopping

# Configurar EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=20)

# Treinar o modelo
history = model.fit(balanced_X_train, balanced_y_train,validation_split= 0.2, epochs=100, callbacks=[early_stopping], batch_size=64)
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 165ms/step - accuracy: 0.6602 - loss: 0.7926 - val_accuracy: 0.5275 - val_loss: 0.8373
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9108 - loss: 0.2182 - val_accuracy: 0.7475 - val_loss: 0.5443
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.9460 - loss: 0.1510 - val_accuracy: 0.9100 - val_loss: 0.1971
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.9615 - loss: 0.1044 - val_accuracy: 0.9150 - val_loss: 0.2051
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9695 - loss: 0.0831 - val_accuracy: 0.9300 - val_loss: 0.1586
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9801 - loss: 0.0579 - val_accuracy: 0.9912 - val_loss: 0.0319
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9902 - loss: 0.0339 - val_accuracy: 0.9937 - val_loss: 0.0241
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9921 - loss: 0.0306 - val_accuracy: 0.9912 - val_loss: 0.0352
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.9930 - loss: 0.0216 - val_accuracy: 0.9912 - val_loss: 0.0200
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.9964 - loss: 0.0144 - val_accuracy: 0.9900 - val_loss: 0.0267
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9946 - loss: 0.0157 - val_accuracy: 0.9937 - val_loss: 0.0145
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9963 - loss: 0.0130 - val_accuracy: 0.9950 - val_loss: 0.0199
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9907 - loss: 0.0250 - val_accuracy: 0.9900 - val_loss: 0.0345
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9933 - loss: 0.0267 - val_accuracy: 0.9900 - val_loss: 0.0172
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9983 - loss: 0.0069 - val_accuracy: 0.9887 - val_loss: 0.0322
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9979 - loss: 0.0110 - val_accuracy: 0.9937 - val_loss: 0.0128
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9985 - loss: 0.0054 - val_accuracy: 0.9962 - val_loss: 0.0085
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.9982 - loss: 0.0071 - val_accuracy: 0.9900 - val_loss: 0.0238
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9968 - loss: 0.0091 - val_accuracy: 0.9962 - val_loss: 0.0067
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.9989 - loss: 0.0052 - val_accuracy: 0.9962 - val_loss: 0.0105
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.9961 - loss: 0.0081 - val_accuracy: 0.9987 - val_loss: 0.0054
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9940 - loss: 0.0105 - val_accuracy: 0.9975 - val_loss: 0.0114
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.9976 - loss: 0.0063 - val_accuracy: 0.9925 - val_loss: 0.0173
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9862 - val_loss: 0.0527
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9927 - loss: 0.0197 - val_accuracy: 0.9950 - val_loss: 0.0069
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9925 - val_loss: 0.0185
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.9986 - loss: 0.0030 - val_accuracy: 0.9937 - val_loss: 0.0069
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9976 - loss: 0.0059 - val_accuracy: 0.9900 - val_loss: 0.0273
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9945 - loss: 0.0127 - val_accuracy: 0.9912 - val_loss: 0.0151
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9989 - loss: 0.0024 - val_accuracy: 0.9950 - val_loss: 0.0078
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9984 - loss: 0.0049 - val_accuracy: 0.9887 - val_loss: 0.0190
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9878 - loss: 0.0414 - val_accuracy: 0.9975 - val_loss: 0.0083
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9950 - loss: 0.0163 - val_accuracy: 0.9962 - val_loss: 0.0175
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9988 - loss: 0.0035 - val_accuracy: 0.9962 - val_loss: 0.0141
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9965 - loss: 0.0061 - val_accuracy: 0.9975 - val_loss: 0.0051
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9963 - loss: 0.0155 - val_accuracy: 0.9937 - val_loss: 0.0141
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9933 - loss: 0.0175 - val_accuracy: 0.9900 - val_loss: 0.0176
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9974 - loss: 0.0068 - val_accuracy: 0.9962 - val_loss: 0.0073
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9887 - val_loss: 0.0268
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9982 - loss: 0.0061 - val_accuracy: 0.9987 - val_loss: 0.0027
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9985 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9987 - val_loss: 0.0024
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9987 - val_loss: 0.0080
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9982 - loss: 0.0052 - val_accuracy: 0.9962 - val_loss: 0.0040
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9979 - loss: 0.0049 - val_accuracy: 0.9987 - val_loss: 0.0034
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9997 - loss: 9.2554e-04 - val_accuracy: 0.9987 - val_loss: 0.0089
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9903 - loss: 0.0298 - val_accuracy: 0.9962 - val_loss: 0.0146
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9855 - loss: 0.0461 - val_accuracy: 0.9975 - val_loss: 0.0091
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9990 - loss: 0.0039 - val_accuracy: 0.9975 - val_loss: 0.0140
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9985 - loss: 0.0044 - val_accuracy: 0.9962 - val_loss: 0.0098
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9948 - loss: 0.0119 - val_accuracy: 0.9887 - val_loss: 0.0586
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9970 - loss: 0.0099 - val_accuracy: 0.9987 - val_loss: 0.0035
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9958 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9987 - val_loss: 0.0091
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9987 - val_loss: 0.0131
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 1.0000 - loss: 2.2572e-04 - val_accuracy: 0.9987 - val_loss: 0.0083
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 1.0000 - loss: 7.1640e-04 - val_accuracy: 0.9987 - val_loss: 0.0091
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9998 - loss: 0.0014 - val_accuracy: 0.9962 - val_loss: 0.0100
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9992 - loss: 0.0016 - val_accuracy: 0.9987 - val_loss: 0.0136
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9983 - loss: 0.0037 - val_accuracy: 0.9987 - val_loss: 0.0035
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9975 - loss: 0.0106 - val_accuracy: 0.9925 - val_loss: 0.0222
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9993 - loss: 0.0017 - val_accuracy: 0.9962 - val_loss: 0.0138
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 1.0000 - loss: 4.2411e-04 - val_accuracy: 0.9975 - val_loss: 0.0090
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 1.0000 - loss: 5.3209e-04 - val_accuracy: 0.9987 - val_loss: 0.0051
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 1.0000 - loss: 6.8288e-04 - val_accuracy: 0.9975 - val_loss: 0.0139
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 1.0000 - loss: 1.7748e-04 - val_accuracy: 0.9987 - val_loss: 0.0082
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 1.3145e-04 - val_accuracy: 0.9987 - val_loss: 0.0081
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9995 - loss: 0.0021 - val_accuracy: 0.9962 - val_loss: 0.0099
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 1.0000 - loss: 3.8401e-04 - val_accuracy: 0.9950 - val_loss: 0.0120
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 1.0000 - loss: 6.0788e-04 - val_accuracy: 0.9987 - val_loss: 0.0056
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9998 - loss: 9.6650e-04 - val_accuracy: 0.9975 - val_loss: 0.0114
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 8.1111e-05
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9993 - loss: 0.0015 - val_accuracy: 0.9987 - val_loss: 0.0027
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9997 - loss: 5.8904e-04 - val_accuracy: 0.9987 - val_loss: 0.0057
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.9973 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9970 - loss: 0.0165 - val_accuracy: 0.9975 - val_loss: 0.0051
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9969 - loss: 0.0085 - val_accuracy: 0.9987 - val_loss: 0.0044
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.9990 - loss: 0.0025 - val_accuracy: 0.9975 - val_loss: 0.0128
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9998 - loss: 9.2391e-04 - val_accuracy: 0.9987 - val_loss: 0.0041
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9998 - loss: 0.0021 - val_accuracy: 0.9962 - val_loss: 0.0059
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.9983 - loss: 0.0038 - val_accuracy: 0.9962 - val_loss: 0.0092
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9978 - loss: 0.0082 - val_accuracy: 0.9925 - val_loss: 0.0427
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9984 - loss: 0.0046 - val_accuracy: 0.9987 - val_loss: 0.0076
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9991 - loss: 0.0018 - val_accuracy: 0.9987 - val_loss: 0.0014
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9968 - loss: 0.0204 - val_accuracy: 0.9950 - val_loss: 0.0143
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9937 - val_loss: 0.0491
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 6.0855e-04 - val_accuracy: 0.9950 - val_loss: 0.0141
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9997 - loss: 4.9121e-04 - val_accuracy: 0.9950 - val_loss: 0.0210
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9992 - loss: 0.0011 - val_accuracy: 0.9950 - val_loss: 0.0234
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9999 - loss: 6.3610e-04 - val_accuracy: 0.9937 - val_loss: 0.0169
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 5.9212e-04
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9967 - loss: 0.0136 - val_accuracy: 0.9950 - val_loss: 0.0187

# %%
val_accuracy = history.history['val_accuracy']

mean_val_accuracy = np.mean(val_accuracy)

print("Valor médio de acurácia:", mean_val_accuracy)
# Out:
# Valor médio de acurácia: 0.9854972990610267

# %% [markdown]
# 5. Carregando o modelo

# %%
import pandas as pd
history_save = pd.DataFrame(history.history)
history_save.to_csv('datasetCAI.csv')

# %%
# save model structure in jason file
model_json = model.to_json()
with open("emotion_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
model.save('modeloCAI.keras')

# %%
from keras.models import load_model

modelo_carregado = load_model('/content/modeloCAI.keras')

# %%
import pandas as pd

history = pd.read_csv('/content/datasetCAI.csv')

# %% [markdown]
# 6. Plotando o modelo

# %%
import matplotlib.pyplot as plt

plt.plot(history['loss'])
plt.plot(history['val_loss'])


plt.ylabel('Perda')
plt.xlabel('Época')
plt.legend(['Treinamento', 'Validação'], loc = 'upper right')
plt.show()

# %%
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Acurácia')
plt.ylabel('Acurácia')
plt.xlabel('Épocas')
plt.legend(['Treinamento', 'Validação'], loc='upper left')
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# 7. Salvando o modelo

# %%
preds = modelo_carregado.predict(X_test)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step

# %%
#Função da Matriz de Confusão

def plot_confusion_matrix(
        cm,
        classes,
        normalize=False,
        title='Confusion matrix',
        cmap=plt.cm.Blues
    ):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    #plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
#Gráfico da Matriz de Confusão

y_test_ = [np.argmax(x) for x in y_test]
preds_ = [np.argmax(x) for x in preds]

cm = confusion_matrix(y_test_, preds_)
plot_confusion_matrix(cm, classes=['Positive', 'Negative Positive'], title='Confusion matrix')
plt.show()
plt.close()
# Out:
# Confusion matrix, without normalization
# [[ 52   2]
#  [ 11 405]]

# %%
#Resultado das predições

n = 4
for t in range(4):
    plt.figure(figsize=(10,10))
    for i in range(n*t, n*(t+1)):
        plt.subplot(1, n, i + 1 - n*t)
        plt.imshow(cv2.cvtColor(X_test[i], cv2.COLOR_BGR2RGB), cmap='gray')
        plt.title('Real: {}\nPredito: {}'.format(classes[np.argmax(y_test[i])], classes[np.argmax(preds[i])]))
        plt.axis('off')
    plt.show()
